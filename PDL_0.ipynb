# %% [markdown]
# <a href="https://colab.research.google.com/github/Gaurav-Adlakha/ws/blob/master/PDL_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# title: "Your Blog Post Title"
# author: "Your Name"
# date: "2025-04-06"
# categories: [Category1, Category2]
# description: "A brief description of your post."
# execute:
#   eval: false
# ---

# %%
# Let's build an image classifier model to distinguish between biryani and pulao using minimal code using fastai

# %% [markdown]
# ## Download and Install the dependency

# %%
# !pip install -Uqq fastai
# !pip install -Uqq duckduckgo_search
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.2/84.2 kB 7.4 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# nbdev 2.4.2 requires fastcore>=1.8.0, but you have fastcore 1.7.29 which is incompatible.

# %%
# !pip install -Uqq duckduckgo_search

# %% [markdown]
# ## Downloading Images with the DuckDuckGo Search API.

# %%
from duckduckgo_search import DDGS #
from fastcore.all import *

def search_images(keywords, max_images=200): return L(DDGS().images(keywords, max_results=max_images)).itemgot('image')

# %%
urls = search_images('biryani photos', max_images=1)
urls[0]
# Out:
# 'https://cdn.shortpixel.ai/client/q_lossy,ret_img,w_1200,h_1799/https://norecipes.com/wp-content/uploads/2017/05/chicken-biryani-12-1200x1799.jpg'

# %% [markdown]
# # Download and display a sample biryani image

# %%
from fastdownload import download_url
dest = 'biryani.jpg'
download_url(urls[0], dest, show_progress=False)

from fastai.vision.all import *
im = Image.open(dest)
im.to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=171x256>

# %% [markdown]
# # Download and display the sample pulao image

# %%
download_url(search_images('pulao photos', max_images=1)[0], 'pulao.jpg', show_progress=False)
Image.open('pulao.jpg').to_thumb(256,256)
# Out:
# <PIL.Image.Image image mode=RGB size=256x221>

# %% [markdown]
# # Download a few sample images and store them in a directory

# %%
searches = 'biryani','pulao'
path = Path('biryani_or_pulao')
from time import sleep

for o in searches:
    dest = (path/o)
    dest.mkdir(exist_ok=True, parents=True)
    download_images(dest, urls=search_images(f'{o} photo'))
    sleep(10)
    resize_images(path/o, max_size=400, dest=path/o)
# Out:
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/PIL/Image.py:1045: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
Path('biryani_or_pulao').ls()
# Out:
# (#2) [Path('biryani_or_pulao/biryani'),Path('biryani_or_pulao/pulao')]

# %%
Path('biryani_or_pulao/biryani').ls()
# Out:
# (#367) [Path('biryani_or_pulao/biryani/3a372c7c-b0ff-44d0-8971-abb31cd8009f.jpg'),Path('biryani_or_pulao/biryani/cf16734c-8e81-4481-9ce6-ec2a0094dadb.jpg'),Path('biryani_or_pulao/biryani/4a45218d-a91d-487e-9a21-042513a06317.jpg'),Path('biryani_or_pulao/biryani/827089cf-fdfa-4245-8cc9-360eab538ff1.png'),Path('biryani_or_pulao/biryani/d0c43292-b6db-4f6a-a4ad-b15471d39261.jpg'),Path('biryani_or_pulao/biryani/8c6de46f-8162-4057-994d-fdd142f18b9d.jpg'),Path('biryani_or_pulao/biryani/3db0ac2e-9c9d-4eb8-bed4-f8362cd61f3f.jpg'),Path('biryani_or_pulao/biryani/04534f4b-4dd0-4cd1-8aef-c50e51d59a55.jpg'),Path('biryani_or_pulao/biryani/ccdd8e08-a900-436c-8988-ee0ee74647df.jpg'),Path('biryani_or_pulao/biryani/bd258788-a487-4cec-bd74-25a41771212c.jpg'),Path('biryani_or_pulao/biryani/22cf8df6-a4fc-47ed-9411-2b14ca22f571.jpg'),Path('biryani_or_pulao/biryani/6dcc6998-5d9c-441e-8d67-3c51e987a145.
# %%
failed = verify_images(get_image_files(path))
failed.map(Path.unlink)
len(failed)
# Out:
# 19

# %% [markdown]
# # Let's create and check our dataset of biryani and pulao images,

# %%
dls = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_image_files,
    splitter=RandomSplitter(valid_pct=0.2, seed=42),
    get_y=parent_label,
    item_tfms=[Resize(192, method='squish')]
).dataloaders(path)

dls.show_batch(max_n=6)

# %% [markdown]
#  # Let's train it using the ResNet-18 architecture for 3 epochs

# %%
learn = vision_learner(dls, resnet18, metrics=error_rate)
learn.fine_tune(3)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.075147</td>
#       <td>0.863011</td>
#       <td>0.316901</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.535140</td>
#       <td>0.435515</td>
#       <td>0.140845</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.325368</td>
#       <td>0.267439</td>
#       <td>0.063380</td>
#       <td>00:02</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.234341</td>
#       <td>0.231905</td>
#       <td>0.091549</td>
#       <td>00:03</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #Let's begin our predictions.

# %%
is_biryani,_,probs = learn.predict(PILImage.create('biryani.jpg'))
print(f"This is a: {is_biryani}.")
print(f"Probability it's a biryani: {probs[0]:.4f}\nProbability it's a pulao image: {probs[1]:.4f}")
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# This is a: pulao.
# Probability it's a biryani: 0.2088
# Probability it's a pulao image: 0.7912

# %%
from fastai.vision.widgets import *

# %%
interp = ClassificationInterpretation.from_learner(learn)
interp.plot_confusion_matrix()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
interp.plot_top_losses(5, nrows=1)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
cleaner = ImageClassifierCleaner(learn)
cleaner
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# VBox(children=(Dropdown(options=('biryani', 'pulao'), value='biryani'), Dropdown(options=('Train', 'Valid'), v…

# %%
for idx in cleaner.delete(): cleaner.fns[idx].unlink()

# %%
for idx,cat in cleaner.change(): shutil.move(str(cleaner.fns[idx]), path/cat)

# %%
# pip install nbdev
# Out:
# Requirement already satisfied: nbdev in /usr/local/lib/python3.11/dist-packages (2.4.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from nbdev) (24.2)
# Requirement already satisfied: fastcore>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from nbdev) (1.8.1)
# Requirement already satisfied: execnb>=0.1.12 in /usr/local/lib/python3.11/dist-packages (from nbdev) (0.1.14)
# Requirement already satisfied: astunparse in /usr/local/lib/python3.11/dist-packages (from nbdev) (1.6.3)
# Requirement already satisfied: ghapi>=1.0.3 in /usr/local/lib/python3.11/dist-packages (from nbdev) (1.0.6)
# Requirement already satisfied: watchdog in /usr/local/lib/python3.11/dist-packages (from nbdev) (6.0.0)
# Requirement already satisfied: asttokens in /usr/local/lib/python3.11/dist-packages (from nbdev) (3.0.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nbdev) (75.2.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from nbdev) (6.0.2)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from execnb>=0.1.12->nbdev) (7.34.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse->nbdev) (0.45.1)
# Requirement already satisfied: six<2.0,>=1.6.1 in /usr/local/lib/python3.11/dist-packages (from astunparse->nbdev) (1.17.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->execnb>=0.1.12->nbdev) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->execnb>=0.1.12->nbdev) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->execnb>=0.1.12->nbdev) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->execnb>=0.1.12->nbdev) (0.2.13)

# %%
# searches = [
#     "Vollkornbrot",       # Whole grain bread, dense and nutty
#     "Roggenbrot",         # Rye bread, tangy and hearty
#     "Pumpernickel",       # Dark, dense rye bread from Westphalia
#     "Brötchen",           # Classic German bread rolls
#     "Brezel",             # Traditional German pretzel
#     "Schwarzbrot",        # Black bread, dark and flavorful
#     "Mischbrot",          # Mixed grain bread, typically wheat and rye
#     "Dinkelbrötchen",     # Spelt rolls, slightly nutty flavor
#     "Sonnenblumenbrot",   # Sunflower seed bread
#     "Landbrot"            # Country bread, rustic and versatile
# ]


# # searches = 'biryani','pulao'
# path = Path('german_breads')
# from time import sleep

# for o in searches:
#     dest = (path/o)
#     dest.mkdir(exist_ok=True, parents=True)
#     download_images(dest, urls=search_images(f'{o} photo'))
#     sleep(10)
#     resize_images(path/o, max_size=400, dest=path/o)
